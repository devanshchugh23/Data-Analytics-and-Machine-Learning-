# %% [markdown]
# #DEVANSH CHUGH
# #210968222

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
df=pd.read_csv("amazon_baby.csv")
df
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating
# 0       These flannel wipes are OK, but in my opinion ...       3
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# ...                                                   ...     ...
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
# [183531 rows x 3 columns]

# %% [markdown]
# # 1. Check the number of the reviews received for each product.

# %%
df['name'].value_counts()
# Out:
# Vulli Sophie the Giraffe Teether                                                                                                                                                                                                                                                                                                                       785
# Simple Wishes Hands-Free Breastpump Bra, Pink, XS-L                                                                                                                                                                                                                                                                                                    562
# Infant Optics DXR-5 2.4 GHz Digital Video Baby Monitor with Night Vision                                                                                                                                                                                                                                                                               561
# Baby Einstein Take Along Tunes                                                                                                                                                                                                                                                                                                                         547
# Cloud b Twilight Constellation Night Light, Turtle                                                                                                                                                                                                                                                                                                     520
#                                                                                                                                                                                                                                                                                                                                                       ...
# The Kids Room The Princess Sleeps Here with Green and Pink Oval Wall Plaque                                                                                                                                                                                                                                                                              1
# Disney Baby Mickey Mouse Fleece Baby Blanket Embroidered Appliqued                                                                                                                                                                                                                                                                                       1
# Philips AVENT BPA Free 6-Pack Bottles - 9 oz.                                                                                                                                                                                                                                                                                                            1
# Philips AVENT 4 Oz. BPA Free Bottles - 6 Pack                                                                                                                                                                                                                                                                                                            1
# Best 2 Pack Baby Car Shade for Kids - Window Shade Baby - Cheapest Baby Sun Shade with Excellent Quality - Great Protection Car Window Shade for Travel, Trips, or Just for Shade - Better Than Britax and Brica - Pop Open Window Shade Cling That Folds to the Size of Your Hand - Twice As Strong As Competitors - Lifetime Money Back Guarantee      1
# Name: name, Length: 32417, dtype: int64

# %% [markdown]
# # 2. Check the products that have more than 15 reviews.

# %%
df1=df.name.value_counts()
rslt_df=df1[df1>15]
rslt_df
# Out:
# Vulli Sophie the Giraffe Teether                                                              785
# Simple Wishes Hands-Free Breastpump Bra, Pink, XS-L                                           562
# Infant Optics DXR-5 2.4 GHz Digital Video Baby Monitor with Night Vision                      561
# Baby Einstein Take Along Tunes                                                                547
# Cloud b Twilight Constellation Night Light, Turtle                                            520
#                                                                                              ...
# Summer Infant Keep Me Clean Disposable Potty Protectors, Green/White,(Pack of 2), 10-Count     16
# Vulli Products - Sophie The Giraffe Teething Ring - Gift Boxed! - 100% Natural rubber          16
# Itzy Ritzy Shopping Cart and High Chair Cover, Avocado Damask                                  16
# The First Years American Red Cross Deluxe Baby Healthcare and Grooming Kit                     16
# Medela 100% Cotton Washable Nursing Bra Pads                                                   16
# Name: name, Length: 2339, dtype: int64

# %% [markdown]
# # 3.Find any missing review are present or not, if present remove those data.

# %%
df2=df[df['review'].notnull()]
df2
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating
# 0       These flannel wipes are OK, but in my opinion ...       3
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# ...                                                   ...     ...
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
# [182702 rows x 3 columns]

# %% [markdown]
# # 4. Clean the data and remove the special characters and replace the contractions with its expansion by converting the uppercase character to lower case. Also, remove the punctuations.

# %%
df2['review']=df2['review'].str.lower()
df2['review'] = df2['review'].str.replace("[^a-zA-Z#]", " ")
df2
# Out:
# C:\Users\DC\AppData\Local\Temp\ipykernel_17968\2085546221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['review']=df2['review'].str.lower()
# C:\Users\DC\AppData\Local\Temp\ipykernel_17968\2085546221.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2['review'] = df2['review'].str.replace("[^a-zA-Z#]", " ")
# C:\Users\DC\AppData\Local\Temp\ipykernel_17968\2085546221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['review'] = df2['review'].str.replace("[^a-zA-Z#]", " ")
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating
# 0       these flannel wipes are ok  but in my opinion ...       3
# 1       it came early and was not disappointed  i love...       5
# 2       very soft and comfortable and warmer than it l...       5
# 3       this is a product well worth the purchase   i ...       5
# 4       all of my kids have cried non stop when i trie...       5
# ...                                                   ...     ...
# 183526  such a great idea  very handy to have and look...       5
# 183527  this product rocks   it is a great blend of fu...       5
# 183528  this item looks great and cool for my kids    ...       5
# 183529  i am extremely happy with this product  i have...       5
# 183530  i love this product very mush   i have bought ...       5
#
# [182702 rows x 3 columns]

# %% [markdown]
# # 5. Add the Polarity, length of the review, the word count and average word length of each review.

# %%
df2["length of the review"]=df2["review"].str.len()
df2["Number of Words"]=df2["review"].apply(lambda n: len(n.split()))
df2["Average"]=df2["length of the review"]/df2["Number of Words"]
df2
# Out:
# C:\Users\DC\AppData\Local\Temp\ipykernel_17968\1055284197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["length of the review"]=df2["review"].str.len()
# C:\Users\DC\AppData\Local\Temp\ipykernel_17968\1055284197.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Number of Words"]=df2["review"].apply(lambda n: len(n.split()))
# C:\Users\DC\AppData\Local\Temp\ipykernel_17968\1055284197.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Average"]=df2["length of the review"]/df2["Number of Words"]
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# ...                                                   ...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating  \
# 0       these flannel wipes are ok  but in my opinion ...       3
# 1       it came early and was not disappointed  i love...       5
# 2       very soft and comfortable and warmer than it l...       5
# 3       this is a product well worth the purchase   i ...       5
# 4       all of my kids have cried non stop when i trie...       5
# ...                                                   ...     ...
# 183526  such a great idea  very handy to have and look...       5
# 183527  this product rocks   it is a great blend of fu...       5
# 183528  this item looks great and cool for my kids    ...       5
# 183529  i am extremely happy with this product  i have...       5
# 183530  i love this product very mush   i have bought ...       5
#
#         length of the review  Number of Words   Average
# 0                        452               78  5.794872
# 1                        158               30  5.266667
# 2                        143               25  5.720000
# 3                        390               74  5.270270
# 4                        405               80  5.062500
# ...                      ...              ...       ...
# 183526                   138               28  4.928571
# 183527                   354               65  5.446154
# 183528                    93               18  5.166667
# 183529                   854              169  5.053254
# 183530                   196               36  5.444444
#
# [182702 rows x 6 columns]
