# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("mtcars.csv")

# %%
df
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.model[(df['mpg']) == np.max(df.mpg)]
# Out:
# 19    Toyota Corolla
# Name: model, dtype: object

# %%
df.model[(df['mpg']) == np.min(df.mpg)]
# Out:
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# Name: model, dtype: object

# %%
df.model[(df['hp']) == np.max(df.hp)]
# Out:
# 30    Maserati Bora
# Name: model, dtype: object

# %%
df.describe().disp
# Out:
# count     32.000000
# mean     230.721875
# std      123.938694
# min       71.100000
# 25%      120.825000
# 50%      196.300000
# 75%      326.000000
# max      472.000000
# Name: disp, dtype: float64

# %%
np.median(df['hp'])
# Out:
# 123.0

# %%
df.loc[df["am"]==0,'mpg'].mean()
# Out:
# 17.147368421052633

# %%
df1['mpg'].mean()
#ForAutomatic
# Out:
# 24.39230769230769

# %%
df1=df.loc[df['am']==1]
df1['mpg'].mean()
#ForManual
# Out:
# 24.39230769230769

# %%
from matplotlib import pyplot as plt

# %%
plt.hist(df.mpg)
plt.title('MPG')
plt.show()

# %%
import seaborn as sbn

# %%
sbn.boxplot(x=df.cyl,y=df.mpg)
# Out:
# <AxesSubplot:xlabel='cyl', ylabel='mpg'>

# %%
pd.crosstab(df.am==0,df.am==1)
# Out:
# am     False  True
# am
# False      0    13
# True      19     0

# %%
pd.crosstab(df.am,df.cyl)
# Out:
# cyl  4  6   8
# am
# 0    3  4  12
# 1    8  3   2

# %%
df["wt"].corr(df["mpg"])
# Out:
# -0.8676593765172281

# %%
pd.crosstab(df.am,0)
# Out:
# col_0   0
# am
# 0      19
# 1      13

# %%
pd.crosstab(df.cyl,df.am)
# Out:
# am    0  1
# cyl
# 4     3  8
# 6     4  3
# 8    12  2

# %%
pd.crosstab(df["model"],df['am'])
# Out:
# am                   0  1
# model
# AMC Javelin          1  0
# Cadillac Fleetwood   1  0
# Camaro Z28           1  0
# Chrysler Imperial    1  0
# Datsun 710           0  1
# Dodge Challenger     1  0
# Duster 360           1  0
# Ferrari Dino         0  1
# Fiat 128             0  1
# Fiat X1-9            0  1
# Ford Pantera L       0  1
# Honda Civic          0  1
# Hornet 4 Drive       1  0
# Hornet Sportabout    1  0
# Lincoln Continental  1  0
# Lotus Europa         0  1
# Maserati Bora        0  1
# Mazda RX4            0  1
# Mazda RX4 Wag        0  1
# Merc 230             1  0
# Merc 240D            1  0
# Merc 280             1  0
# Merc 280C            1  0
# Merc 450SE           1  0
# Merc 450SL           1  0
# Merc 450SLC          1  0
# Pontiac Firebird     1  0
# Porsche 914-2        0  1
# Toyota Corolla       0  1
# Toyota Corona        1  0
# Valiant              1  0
# Volvo 142E           0  1

# %%
plt.xlabel('mpg')
plt.ylabel('wt(tons)')
plt.scatter(df.wt,df.mpg)

# %%
np.corrcoef(df.wt, df.mpg)
# Out:
# array([[ 1.        , -0.86765938],
#        [-0.86765938,  1.        ]])
